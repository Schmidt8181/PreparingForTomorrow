# %%
import numpy as np
import pandas as pd
import pyflux as pf
import scipy
from datetime import datetime
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # get data

# %%
import os
curr_directory = os.getcwd()
datafile = curr_directory + "/data/Food_price_indices_data_jul.csv"
food_data = pd.read_csv(datafile)
food_data.head()
# Out:
#      Date  Food Price Index  Meat Price Index  Dairy Price Index  \
# 0  1/1990             108.7             112.3               94.3
# 1  2/1990             109.9             117.7               91.9
# 2  3/1990             107.9             119.6               73.6
# 3  4/1990             114.2             131.0               85.2
# 4  5/1990             111.2             130.5               70.0
#
#    Cereals Price Index  Oils Price Index  Sugar Price Index
# 0                106.4              73.0              201.5
# 1                104.0              72.5              207.9
# 2                102.1              74.6              218.0
# 3                105.1              71.8              216.3
# 4                105.3              74.4              207.2

# %%
food_data.tail(12)
# Out:
#         Date  Food Price Index  Meat Price Index  Dairy Price Index  \
# 330   7/2017             179.0             174.9              216.6
# 331   8/2017             177.2             174.3              219.7
# 332   9/2017             178.6             174.0              224.2
# 333  10/2017             176.5             173.1              214.8
# 334  11/2017             175.7             172.8              204.2
# 335  12/2017             169.1             169.7              184.4
# 336   1/2018             168.4             167.5              179.9
# 337   2/2018             171.4             170.3              191.1
# 338   3/2018             173.2             171.0              197.4
# 339   4/2018             174.0             170.4              204.1
# 340   5/2018             176.1             169.3              215.2
# 341   6/2018             173.7             169.8              213.2
#
#      Cereals Price Index  Oils Price Index  Sugar Price Index
# 330                162.2             160.4              207.5
# 331                153.0             164.4              203.9
# 332                151.9             171.9              204.2
# 333                152.7             170.0              203.5
# 334                153.1             172.2              212.7
# 335                152.4             162.6              204.1
# 336                156.6             163.1              199.9
# 337                161.3             158.0              192.4
# 338                165.4             156.8              185.5
# 339                168.5             154.6              176.1
# 340                172.6             150.6              175.3
# 341                166.2             146.1              177.4

# %%
datafile2 = curr_directory + "/data/GLB.Ts+dSST.csv"
temperature_data = pd.read_csv(datafile2)
temperature_data.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul    Aug    Sep    Oct    Nov  \
# 0  1880 -0.29 -0.18 -0.11 -0.19 -0.11 -0.23 -0.20  -0.09  -0.15  -0.23   -0.2
# 1  1881 -0.15 -0.17  0.04  0.04  0.02 -0.20 -0.06  -0.02  -0.13   -0.2  -0.21
# 2  1882  0.15  0.15  0.04 -0.18 -0.16 -0.25 -0.20  -0.05  -0.09  -0.24  -0.16
# 3  1883 -0.31 -0.38 -0.12 -0.17 -0.20 -0.12 -0.08  -0.15   -0.2  -0.14  -0.22
# 4  1884 -0.15 -0.08 -0.37 -0.42 -0.36 -0.40 -0.34  -0.26  -0.27  -0.24  -0.29
#
#      Dec    J-D    D-N    DJF   MAM    JJA    SON
# 0  -0.22  -0.18    ***    *** -0.14  -0.17  -0.19
# 1   -0.1  -0.09   -0.1  -0.18  0.04  -0.09  -0.18
# 2  -0.24   -0.1  -0.09   0.07 -0.10  -0.17  -0.16
# 3  -0.15  -0.19  -0.19  -0.31 -0.16  -0.11  -0.19
# 4  -0.27  -0.29  -0.28  -0.13 -0.38  -0.33  -0.27

# %% [markdown]
# # clean the data

# %%
from cleaning import cleaning

# %%
clean_temp_data = cleaning.clean_temperature_data(temperature_data)
# Out:
#           Date  Temperature
# 341 2018-06-01         0.76
# 342 2018-07-01         0.78
# 343 2018-08-01          NaN
# 344 2018-09-01          NaN
# 345 2018-10-01          NaN
# 346 2018-11-01          NaN
# 347 2018-12-01          NaN

# %%
clean_temp_data.dtypes
# Out:
# Date           datetime64[ns]
# Temperature           float64
# dtype: object

# %%
clean_food_data = cleaning.clean_food_data(food_data)
# Out:
#           Date  Meat Price Index  Dairy Price Index  Cereals Price Index  \
# 330 2017-07-01             174.9              216.6                162.2
# 331 2017-08-01             174.3              219.7                153.0
# 332 2017-09-01             174.0              224.2                151.9
# 333 2017-10-01             173.1              214.8                152.7
# 334 2017-11-01             172.8              204.2                153.1
# 335 2017-12-01             169.7              184.4                152.4
# 336 2018-01-01             167.5              179.9                156.6
# 337 2018-02-01             170.3              191.1                161.3
# 338 2018-03-01             171.0              197.4                165.4
# 339 2018-04-01             170.4              204.1                168.5
# 340 2018-05-01             169.3              215.2                172.6
# 341 2018-06-01             169.8              213.2                166.2
#
#      Oils Price Index  Sugar Price Index
# 330             160.4              207.5
# 331             164.4              203.9
# 332             171.9              204.2
# 333             170.0              203.5
# 334             172.2              212.7
# 335             162.6              204.1
# 336             163.1              199.9
# 337             158.0              192.4
# 338             156.8              185.5
# 339             154.6              176.1
# 340             150.6              175.3
# 341             146.1              177.4

# %%
clean_food_data['Temperature'] = clean_temp_data['Temperature']

# %%
clean_food_data.tail()
# Out:
#           Date  Meat Price Index  Dairy Price Index  Cereals Price Index  \
# 337 2018-02-01             170.3              191.1                161.3
# 338 2018-03-01             171.0              197.4                165.4
# 339 2018-04-01             170.4              204.1                168.5
# 340 2018-05-01             169.3              215.2                172.6
# 341 2018-06-01             169.8              213.2                166.2
#
#      Oils Price Index  Sugar Price Index  Temperature
# 337             158.0              192.4         0.81
# 338             156.8              185.5         0.91
# 339             154.6              176.1         0.87
# 340             150.6              175.3         0.82
# 341             146.1              177.4         0.76

# %%
clean_food_data.dtypes
# Out:
# Date                   datetime64[ns]
# Meat Price Index              float64
# Dairy Price Index             float64
# Cereals Price Index           float64
# Oils Price Index              float64
# Sugar Price Index             float64
# Temperature                   float64
# dtype: object

# %%
# export cleaned and combined data to csv file
#clean_food_data.to_csv('clean_food_data.csv')

# %%
indexed_df = clean_food_data.set_index(['Date'])

# %% [markdown]
# # Data exploration and visualization
# don't forget that the data is on a scale of 2002-2004 = 100.0

# %%
indexed_df.describe()
# Out:
#        Meat Price Index  Dairy Price Index  Cereals Price Index  \
# count        336.000000         336.000000           336.000000
# mean         135.340774         139.432440           136.972321
# std           30.461120          57.092038            50.730166
# min           84.500000          66.100000            80.200000
# 25%          113.600000          93.275000            97.750000
# 50%          128.050000         116.250000           112.500000
# 75%          159.300000         185.950000           163.925000
# max          212.000000         275.400000           267.700000
#
#        Oils Price Index  Sugar Price Index  Temperature
# count        336.000000         336.000000   336.000000
# mean         134.397024         182.013393     0.560446
# std           53.584062          74.900003     0.214049
# min           57.100000          72.900000     0.000000
# 25%           90.125000         127.275000     0.410000
# 50%          120.450000         165.950000     0.560000
# 75%          167.675000         222.150000     0.690000
# max          286.500000         420.200000     1.340000

# %%
indexed_df.head()
# Out:
#             Meat Price Index  Dairy Price Index  Cereals Price Index  \
# Date
# 1990-01-01             112.3               94.3                106.4
# 1990-02-01             117.7               91.9                104.0
# 1990-03-01             119.6               73.6                102.1
# 1990-04-01             131.0               85.2                105.1
# 1990-05-01             130.5               70.0                105.3
#
#             Oils Price Index  Sugar Price Index  Temperature
# Date
# 1990-01-01              73.0              201.5         0.41
# 1990-02-01              72.5              207.9         0.40
# 1990-03-01              74.6              218.0         0.44
# 1990-04-01              71.8              216.3         0.37
# 1990-05-01              74.4              207.2         0.27

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = indexed_df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool),
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
pd.plotting.scatter_matrix(indexed_df, alpha = 0.3, figsize = (14,14), diagonal = 'kde');

# %%
# checking for collinearity
food_corr = np.corrcoef(indexed_df, rowvar=False)
eig_val, eig_vec = np.linalg.eig(food_corr)
eig_val
# Out:
# array([4.21331106, 1.00150663, 0.37066726, 0.22398565, 0.05751236,
#        0.13301704])

# %%
indexed_df.plot()
plt.show()

# %%
indexed_df.hist(figsize=(8,8))
plt.show()

# %% [markdown]
# # feature engineering

# %%
from statsmodels.tsa.stattools import adfuller

# %%
df_diff = indexed_df.diff()

# %%
df_diff.head()
# Out:
#             Meat Price Index  Dairy Price Index  Cereals Price Index  \
# Date
# 1990-01-01               NaN                NaN                  NaN
# 1990-02-01               5.4               -2.4                 -2.4
# 1990-03-01               1.9              -18.3                 -1.9
# 1990-04-01              11.4               11.6                  3.0
# 1990-05-01              -0.5              -15.2                  0.2
#
#             Oils Price Index  Sugar Price Index  Temperature
# Date
# 1990-01-01               NaN                NaN          NaN
# 1990-02-01              -0.5                6.4        -0.01
# 1990-03-01               2.1               10.1         0.04
# 1990-04-01              -2.8               -1.7        -0.07
# 1990-05-01               2.6               -9.1        -0.10

# %%
df_diff.plot()
plt.show()

# %%
pd.plotting.scatter_matrix(df_diff, alpha = 0.3, figsize = (14,14), diagonal = 'kde');

# %%
def test_fuller(df):
    result = adfuller(df[1:])
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key, value))

# %%
test_fuller(df_diff['Meat Price Index'])
# Out:
# ADF Statistic: -5.194921
# p-value: 0.000009
# Critical Values:
# 	1%: -3.451
# 	5%: -2.871
# 	10%: -2.572

# %%
test_fuller(df_diff['Cereals Price Index'])
# Out:
# ADF Statistic: -4.885484
# p-value: 0.000037
# Critical Values:
# 	1%: -3.451
# 	5%: -2.871
# 	10%: -2.572

# %%
test_fuller(df_diff['Dairy Price Index'])
# Out:
# ADF Statistic: -6.605227
# p-value: 0.000000
# Critical Values:
# 	1%: -3.451
# 	5%: -2.871
# 	10%: -2.572

# %%
test_fuller(df_diff['Oils Price Index'])
# Out:
# ADF Statistic: -5.586205
# p-value: 0.000001
# Critical Values:
# 	1%: -3.451
# 	5%: -2.871
# 	10%: -2.572

# %%
test_fuller(df_diff['Sugar Price Index'])
# Out:
# ADF Statistic: -12.099975
# p-value: 0.000000
# Critical Values:
# 	1%: -3.450
# 	5%: -2.870
# 	10%: -2.571

# %% [markdown]
# all adfuller tests show that the differenced data is stationary
#
# next step is to split df into different frames for each index? then to label each frame with if the index went up or down

# %%
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return np.array(diff)

# %%
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
len(indexed_df)
# Out:
# 336

# %%
year_diff_df = pd.DataFrame()
year_diff_df['Sugar_diff_yr'] = difference(indexed_df['Sugar Price Index'], interval=12)
year_diff_df['Oils_diff_yr'] = difference(indexed_df['Oils Price Index'], interval=12)
year_diff_df['Dairy_diff_yr'] = difference(indexed_df['Dairy Price Index'], interval=12)
year_diff_df['Cereals_diff_yr'] = difference(indexed_df['Cereals Price Index'], interval=12)
year_diff_df['Meat_diff_yr'] = difference(indexed_df['Meat Price Index'], interval=12)
year_diff_df['Temperature_diff_df'] = difference(indexed_df['Temperature'], interval=12)

# %%
len(year_diff_df)
# Out:
# 324

# %%
year_diff_df.plot()
plt.show()

# %%
pd.plotting.scatter_matrix(year_diff_df, alpha = 0.3, figsize = (14,14), diagonal = 'kde');

# %%
food_data['Year'], food_data['Month'] = food_data['Date'].dt.year, food_data['Date'].dt.month

food_data['Season_NH'] = food_data['Date'].apply(lambda dt: (dt.month%12 + 3)//3)

# %%
food_data.head()
# Out:
#         Date  Food Price Index  Meat Price Index  Dairy Price Index  \
# 0 1990-01-01             108.7             112.3               94.3
# 1 1990-02-01             109.9             117.7               91.9
# 2 1990-03-01             107.9             119.6               73.6
# 3 1990-04-01             114.2             131.0               85.2
# 4 1990-05-01             111.2             130.5               70.0
#
#    Cereals Price Index  Oils Price Index  Sugar Price Index  Year  Month  \
# 0                106.4              73.0              201.5  1990      1
# 1                104.0              72.5              207.9  1990      2
# 2                102.1              74.6              218.0  1990      3
# 3                105.1              71.8              216.3  1990      4
# 4                105.3              74.4              207.2  1990      5
#
#    Season_NH
# 0          1
# 1          1
# 2          2
# 3          2
# 4          2

# %% [markdown]
# # Unsupervised learning

# %%
# do some kind of unsupervised learning here

# %% [markdown]
# # Time series analysis

# %%
split_point = len(df_diff) - 70
diff_dataset, diff_validation = df_diff[1:split_point], df_diff[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
#dataset.to_csv('dataset.csv')
#validation.to_csv('validation.csv')
# Out:
# Dataset 265, Validation 70

# %%
diff_dataset.head()
# Out:
#             Meat Price Index  Dairy Price Index  Cereals Price Index  \
# Date
# 1990-02-01               5.4               -2.4                 -2.4
# 1990-03-01               1.9              -18.3                 -1.9
# 1990-04-01              11.4               11.6                  3.0
# 1990-05-01              -0.5              -15.2                  0.2
# 1990-06-01               2.2                0.0                 -2.2
#
#             Oils Price Index  Sugar Price Index  Temperature
# Date
# 1990-02-01              -0.5                6.4        -0.01
# 1990-03-01               2.1               10.1         0.04
# 1990-04-01              -2.8               -1.7        -0.07
# 1990-05-01               2.6               -9.1        -0.10
# 1990-06-01              -2.7              -23.2         0.24

# %%
indexed_df.head()
# Out:
#             Meat Price Index  Dairy Price Index  Cereals Price Index  \
# Date
# 1990-01-01             112.3               94.3                106.4
# 1990-02-01             117.7               91.9                104.0
# 1990-03-01             119.6               73.6                102.1
# 1990-04-01             131.0               85.2                105.1
# 1990-05-01             130.5               70.0                105.3
#
#             Oils Price Index  Sugar Price Index  Temperature
# Date
# 1990-01-01              73.0              201.5         0.41
# 1990-02-01              72.5              207.9         0.40
# 1990-03-01              74.6              218.0         0.44
# 1990-04-01              71.8              216.3         0.37
# 1990-05-01              74.4              207.2         0.27

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(food_data)
plt.show()

# %% [markdown]
# That looks like the first 80-ish lags are very significant. Lets split the dataset in half and see what we get then. The data starts in 1990 and doesn't become volitile until 2007(ish).

# %%
UpTo2006 = food_data[:192]
After2005 = food_data[192:]

# %%
autocorrelation_plot(UpTo2006['Sugar Price Index'])
plt.show()

# %%
autocorrelation_plot(After2005['Sugar Price Index'])
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(indexed_df['Sugar Price Index'], order=(25,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                               ARIMA Model Results
# ===============================================================================
# Dep. Variable:     D.Sugar Price Index   No. Observations:                  335
# Model:                 ARIMA(25, 1, 0)   Log Likelihood               -1343.314
# Method:                        css-mle   S.D. of innovations             13.313
# Date:                 Mon, 10 Sep 2018   AIC                           2740.629
# Time:                         18:52:50   BIC                           2843.610
# Sample:                     02-01-1990   HQIC                          2781.684
#                           - 12-01-2017
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.0793      0.705      0.112      0.911      -1.302       1.461
# ar.L1.D.Sugar Price Index      0.3507      0.055      6.415      0.000       0.244       0.458
# ar.L2.D.Sugar Price Index     -0.1289      0.058     -2.232      0.026      -0.242      -0.016
# ar.L3.D.Sugar Price Index      0.0646      0.058      1.113      0.267      -0.049       0.178
# ar.L4.D.Sugar Price Index     -0.0695      0.058     -1.196      0.233      -0.183       0.044
# ar.L5.D.Sugar Price Index      0.0283      0.059      0.483      0.629      -0.087       0.143
# ar.L6.D.Sugar Price Index     -0.0697      0.059     -1.180      0.239      -0.185       0.046
# ar.L7.D.Sugar Price Index     -0.0709      0.060     -1.174      0.241      -0.189       0.047
# ar.L8.D.Sugar Price Index     -0.0472      0.061     -0.777      0.438      -0.166       0.072
# ar.L9.D.Sugar Price Index     -0.0237      0.061     -0.391      0.696      -0.143       0.095
# ar.L10.D.Sugar Price Index    -0.0521      0.060     -0.863      0.389      -0.170       0.066
# ar.L11.D.Sugar Price Index     0.0111      0.060      0.184      0.854      -0.107       0.130
# ar.L12.D.Sugar Price Index     0.0654      0.061      1.080      0.281      -0.053       0.184
# ar.L13.D.Sugar Price Index     0.0181      0.061      0.295      0.768      -0.102       0.138
# ar.L14.D.Sugar Price Index    -0.0682      0.061     -1.115      0.266      -0.188       0.052
# ar.L15.D.Sugar Price Index    -0.0681      0.061     -1.111      0.267      -0.188       0.052
# ar.L16.D.Sugar Price Index    -0.0919      0.061     -1.501      0.134      -0.212       0.028
# ar.L17.D.Sugar Price Index     0.1342      0.062      2.177      0.030       0.013       0.255
# ar.L18.D.Sugar Price Index     0.0165      0.062      0.265      0.791      -0.105       0.138
# ar.L19.D.Sugar Price Index     0.0101      0.062      0.161      0.872      -0.112       0.132
# ar.L20.D.Sugar Price Index    -0.0033      0.062     -0.053      0.958      -0.125       0.118
# ar.L21.D.Sugar Price Index    -0.0179      0.062     -0.287      0.774      -0.140       0.104
# ar.L22.D.Sugar Price Index    -0.0292      0.063     -0.461      0.645      -0.153       0.095
# ar.L23.D.Sugar Price Index    -0.0834      0.064     -1.311      0.191      -0.208       0.041
# ar.L24.D.Sugar Price Index     0.1078      0.063      1.704      0.089      -0.016       0.232
# ar.L25.D.Sugar Price Index    -0.0271      0.059     -0.459      0.646      -0.143       0.089
#                                     Roots
# ==============================================================================
#                   Real           Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.1251           -0.0000j            1.1251           -0.5000
# AR.2            -1.0461           -0.2739j            1.0813           -0.4592
# AR.3            -1.0461           +0.2739j            1.0813            0.4592
# AR.4            -0.9077           -0.5626j            1.0679           -0.4117
# AR.5            -0.9077           +0.5626j            1.0679            0.4117
# AR.6            -0.7558           -0.8082j            1.1065           -0.3697
# AR.7            -0.7558           +0.8082j            1.1065            0.3697
# AR.8            -0.5446           -0.9325j            1.0798           -0.3341
# AR.9            -0.5446           +0.9325j            1.0798            0.3341
# AR.10           -0.2579           -1.0416j            1.0731           -0.2886
# AR.11           -0.2579           +1.0416j            1.0731            0.2886
# AR.12            0.0712           -1.0702j            1.0726           -0.2394
# AR.13            0.0712           +1.0702j            1.0726            0.2394
# AR.14            0.2905           -1.1055j            1.1430           -0.2091
# AR.15            0.2905           +1.1055j            1.1430            0.2091
# AR.16            0.5320           -0.8946j            1.0408           -0.1646
# AR.17            0.5320           +0.8946j            1.0408            0.1646
# AR.18            0.8528           -0.6821j            1.0920           -0.1074
# AR.19            0.8528           +0.6821j            1.0920            0.1074
# AR.20            1.0371           -0.4571j            1.1334           -0.0661
# AR.21            1.0371           +0.4571j            1.1334            0.0661
# AR.22            1.1602           -0.2548j            1.1878           -0.0344
# AR.23            1.1602           +0.2548j            1.1878            0.0344
# AR.24            1.6277           -0.0000j            1.6277           -0.0000
# AR.25            2.6122           -0.0000j            2.6122           -0.0000
# ------------------------------------------------------------------------------
#                 0
# count  335.000000
# mean    -0.051454
# std     13.353756
# min    -75.317432
# 25%     -7.782964
# 50%     -0.543018
# 75%      6.908887
# max     51.122235

# %%
model2 = ARIMA(indexed_df['Sugar Price Index'], order=(25,1,12))
model_fit2 = model2.fit(disp=0)
print(model_fit2.summary())
# plot residual errors
residuals2 = pd.DataFrame(model_fit2.resid)
residuals2.plot()
plt.show()
residuals2.plot(kind='kde')
plt.show()
print(residuals2.describe())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-64327dd5a228> in <module>()
#       1 model2 = ARIMA(indexed_df['Sugar Price Index'], order=(25,1,12))
# ----> 2 model_fit2 = model2.fit(disp=0)
#       3 print(model_fit2.summary())
#       4 # plot residual errors
#       5 residuals2 = pd.DataFrame(model_fit2.resid)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1149                                            method, transparams, solver,
#    1150                                            maxiter, full_output, disp,
# -> 1151                                            callback, start_ar_lags, **kwargs)
#    1152         normalized_cov_params = None  # TODO: fix this?
#    1153         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     967                                        maxiter=maxiter,
#     968                                        full_output=full_output, disp=disp,
# --> 969                                        callback=callback, **kwargs)
#     970         params = mlefit.params
#     971
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     449                                                        callback=callback,
#     450                                                        retall=retall,
# --> 451                                                        full_output=full_output)
#     452
#     453         #NOTE: this is for fit_regularized and should be generalized
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     182                             disp=disp, maxiter=maxiter, callback=callback,
#     183                             retall=retall, full_output=full_output,
# --> 184                             hess=hessian)
#     185
#     186         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     376                                          callback=callback, args=fargs,
#     377                                          bounds=bounds, disp=disp,
# --> 378                                          **extra_kwargs)
#     379
#     380     if full_output:
#
# /anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# /anaconda/lib/python3.6/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     641         ei[k] = 1.0
#     642         d = epsilon * ei
# --> 643         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     644         ei[k] = 0.0
#     645     return grad
#
# /anaconda/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in <lambda>(params, *args)
#     427
#     428         nobs = self.endog.shape[0]
# --> 429         f = lambda params, *args: -self.loglike(params, *args) / nobs
#     430         score = lambda params, *args: -self.score(params, *args) / nobs
#     431         try:
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     788         method = self.method
#     789         if method in ['mle', 'css-mle']:
# --> 790             return self.loglike_kalman(params, set_sigma2)
#     791         elif method == 'css':
#     792             return self.loglike_css(params, set_sigma2)
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     798         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     799         """
# --> 800         return KalmanFilter.loglike(params, self, set_sigma2)
#     801
#     802     def loglike_css(self, params, set_sigma2=True):
#
# /anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     647             loglike, sigma2 =  kalman_loglike.kalman_loglike_double(y, k,
#     648                                     k_ar, k_ma, k_lags, int(nobs), Z_mat,
# --> 649                                     R_mat, T_mat)
#     650         elif issubdtype(paramsdtype, complex):
#     651             loglike, sigma2 =  kalman_loglike.kalman_loglike_complex(y, k,
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double (statsmodels/tsa/kalmanf/kalman_loglike.c:6510)()
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double (statsmodels/tsa/kalmanf/kalman_loglike.c:3560)()
#
# /anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py in pinv(a, rcond)
#    1722         return wrap(res)
#    1723     a = a.conjugate()
# -> 1724     u, s, vt = svd(a, full_matrices=False)
#    1725
#    1726     # discard small singular values
#
# /anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1442
#    1443         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1444         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1445         u = u.astype(result_t, copy=False)
#    1446         s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
# fit model
model3 = ARIMA(indexed_df['Sugar Price Index'], order=(7,0,1))
model_fit = model3.fit(disp=0)
# one-step out of sample forecast
start_index = len(dataset)
end_index = len(dataset)
forecast = model_fit.predict(start=start_index, end=end_index)
# invert the differenced forecast to something usable
forecast = inverse_difference(indexed_df['Sugar Price Index'], forecast, 12)
print('Forecast: %f' % forecast)

# %%
indexed_df.head()
# Out:
#             Meat Price Index  Dairy Price Index  Cereals Price Index  \
# Date
# 1990-01-01             112.3               94.3                106.4
# 1990-02-01             117.7               91.9                104.0
# 1990-03-01             119.6               73.6                102.1
# 1990-04-01             131.0               85.2                105.1
# 1990-05-01             130.5               70.0                105.3
#
#             Oils Price Index  Sugar Price Index  Temperature
# Date
# 1990-01-01              73.0              201.5         0.41
# 1990-02-01              72.5              207.9         0.40
# 1990-03-01              74.6              218.0         0.44
# 1990-04-01              71.8              216.3         0.37
# 1990-05-01              74.4              207.2         0.27

# %%
# try VAR from Pyflux
indexed_prices = np.log(indexed_df)
plt.figure(figsize=(15,5));
plt.plot(indexed_prices.index,indexed_prices);
#plt.legend(opening_prices.columns.values,loc=3);
plt.title("Logged Index price");

# %%
VAR_model = pf.VAR(data=indexed_df, lags=2, integ=1)

# %%
VARx = VAR_model.fit()
VARx.summary()
# Out:
# VAR(2)
# ======================================================= ==================================================
# Dependent Variable: Differenced Meat Price Index,Differ Method: OLS
# Start Date: 1990-03-01 00:00:00                         Log Likelihood: -5327.8839
# End Date: 2017-12-01 00:00:00                           AIC: 10853.7678
# Number of observations: 333                             BIC: 11230.7739
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Differenced Meat Price Index Constant    0.0505     0.1856     0.2719   0.7857   (-0.3132 | 0.4141)
# Differenced Meat Price Index AR(1)       0.1826     0.3288     0.5553   0.5787   (-0.4618 | 0.8269)
# Differenced Dairy Price Index to Differe -0.0557    0.3191     -0.1746  0.8614   (-0.6811 | 0.5697)
# Differenced Cereals Price Index to Diffe 0.0476     0.385      0.1237   0.9016   (-0.7069 | 0.8021)
# Differenced Oils Price Index to Differen 0.0029     0.7507     0.0038   0.997    (-1.4685 | 1.4742)
# Differenced Sugar Price Index to Differe -0.011     0.0104     -1.0501  0.2937   (-0.0314 | 0.0095)
# Differenced Temperature to Differenced M 0.4048     0.0524     7.7313   0.0      (0.3022 | 0.5075)
# Differenced Meat Price Index AR(2)       0.166      0.0928     1.789    0.0736   (-0.0159 | 0.3478)
# Differenced Dairy Price Index to Differe 0.0803     0.09       0.8913   0.3728   (-0.0962 | 0.2568)
# Differenced Cereals Price Index to Diffe 0.0677     0.1086     0.6234   0.533    (-0.1452 | 0.2806)
# Differenced Oils Price Index to Differen 0.0402     0.2118     0.1896   0.8496   (-0.375 | 0.4554)
# Differenced Sugar Price Index to Differe 0.0234     0.0029     7.9438   0.0      (0.0176 | 0.0292)
# Differenced Temperature to Differenced M -0.1215    0.0314     -3.8736  0.0001   (-0.183 | -0.06)
# Differenced Dairy Price Index Constant   0.1063     0.0556     1.9132   0.0557   (-0.0026 | 0.2153)
# Differenced Dairy Price Index AR(1)      -0.0466    0.0539     -0.8646  0.3872   (-0.1524 | 0.0591)
# Differenced Meat Price Index to Differen 0.5176     0.0651     7.9538   0.0      (0.39 | 0.6451)
# Differenced Cereals Price Index to Diffe 0.0713     0.1269     0.5617   0.5743   (-0.1774 | 0.32)
# Differenced Oils Price Index to Differen 0.1329     0.0018     75.3245  0.0      (0.1294 | 0.1363)
# Differenced Sugar Price Index to Differe -0.0469    0.0361     -1.2984  0.1941   (-0.1176 | 0.0239)
# Differenced Temperature to Differenced D 0.9423     0.0639     14.7379  0.0      (0.817 | 1.0676)
# Differenced Dairy Price Index AR(2)      0.0889     0.0621     1.433    0.1519   (-0.0327 | 0.2106)
# Differenced Meat Price Index to Differen -0.0143    0.0749     -0.1904  0.849    (-0.161 | 0.1325)
# Differenced Cereals Price Index to Diffe -0.0209    0.146      -0.1435  0.8859   (-0.3071 | 0.2652)
# Differenced Oils Price Index to Differen -0.0183    0.002      -9.0181  0.0      (-0.0223 | -0.0143)
# Differenced Sugar Price Index to Differe 0.0232     0.03       0.7718   0.4402   (-0.0356 | 0.082)
# Differenced Temperature to Differenced D 2.7967     0.0532     52.6137  0.0      (2.6925 | 2.9008)
# Differenced Cereals Price Index Constant 0.0719     0.0516     1.393    0.1636   (-0.0293 | 0.173)
# Differenced Cereals Price Index AR(1)    -0.1282    0.0622     -2.0605  0.0394   (-0.2502 | -0.0063)
# Differenced Meat Price Index to Differen 0.0433     0.1214     0.3564   0.7215   (-0.1946 | 0.2811)
# Differenced Dairy Price Index to Differe 0.3007     0.0017     178.2179 0.0      (0.2974 | 0.304)
# Differenced Oils Price Index to Differen 0.1055     0.0137     7.7022   0.0      (0.0787 | 0.1324)
# Differenced Sugar Price Index to Differe -0.023     0.0243     -0.9477  0.3433   (-0.0706 | 0.0246)
# Differenced Temperature to Differenced C 1.0261     0.0236     43.5471  0.0      (0.98 | 1.0723)
# Differenced Cereals Price Index AR(2)    -0.0946    0.0284     -3.3263  0.0009   (-0.1503 | -0.0388)
# Differenced Meat Price Index to Differen 0.023      0.0554     0.4155   0.6777   (-0.0856 | 0.1317)
# Differenced Dairy Price Index to Differe 0.0737     0.0008     95.632   0.0      (0.0722 | 0.0752)
# Differenced Oils Price Index to Differen 0.0197     0.9611     0.0205   0.9836   (-1.8641 | 1.9035)
# Differenced Sugar Price Index to Differe -0.0084    1.7028     -0.0049  0.9961   (-3.3459 | 3.3292)
# Differenced Temperature to Differenced C 0.9229     1.6528     0.5584   0.5766   (-2.3166 | 4.1623)
# Differenced Oils Price Index Constant    0.1533     1.9939     0.0769   0.9387   (-3.7548 | 4.0613)
# Differenced Oils Price Index AR(1)       -0.0927    3.8882     -0.0238  0.981    (-7.7135 | 7.5282)
# Differenced Meat Price Index to Differen 0.0831     0.054      1.5368   0.1243   (-0.0229 | 0.189)
# Differenced Dairy Price Index to Differe 0.1214     0.0519     2.3388   0.0193   (0.0197 | 0.2231)
# Differenced Cereals Price Index to Diffe 0.3594     0.0919     3.9086   0.0001   (0.1792 | 0.5396)
# Differenced Sugar Price Index to Differe -0.0075    0.0892     -0.0841  0.9329   (-0.1824 | 0.1674)
# Differenced Temperature to Differenced O 2.9507     0.1077     27.4085  0.0      (2.7397 | 3.1617)
# Differenced Oils Price Index AR(2)       -0.213     0.2099     -1.0146  0.3103   (-0.6245 | 0.1985)
# Differenced Meat Price Index to Differen 0.0623     0.0029     21.3494  0.0      (0.0566 | 0.068)
# Differenced Dairy Price Index to Differe 0.0758     0.0309     2.4507   0.0143   (0.0152 | 0.1364)
# Differenced Cereals Price Index to Diffe -0.1007    0.0548     -1.8369  0.0662   (-0.208 | 0.0067)
# Differenced Sugar Price Index to Differe 0.0082     0.0532     0.1549   0.8769   (-0.096 | 0.1125)
# Differenced Temperature to Differenced O 2.0618     0.0642     32.1344  0.0      (1.936 | 2.1875)
# Differenced Sugar Price Index Constant   -0.1219    0.1251     -0.974   0.3301   (-0.3671 | 0.1234)
# Differenced Sugar Price Index AR(1)      -0.1996    0.0017     -114.745 0.0      (-0.203 | -0.1962)
# Differenced Meat Price Index to Differen 0.1911     0.0362     5.2775   0.0      (0.1201 | 0.262)
# Differenced Dairy Price Index to Differe -0.2068    0.0641     -3.2236  0.0013   (-0.3325 | -0.0811)
# Differenced Cereals Price Index to Diffe 0.1344     0.0623     2.1588   0.0309   (0.0124 | 0.2564)
# Differenced Oils Price Index to Differen 0.3734     0.0751     4.9714   0.0      (0.2262 | 0.5206)
# Differenced Temperature to Differenced S 8.5264     0.1465     58.2145  0.0      (8.2394 | 8.8135)
# Differenced Sugar Price Index AR(2)      0.0116     0.002      5.6832   0.0      (0.0076 | 0.0156)
# Differenced Meat Price Index to Differen -0.0499    0.0308     -1.6199  0.1052   (-0.1104 | 0.0105)
# Differenced Dairy Price Index to Differe 0.3035     0.0546     5.5559   0.0      (0.1964 | 0.4106)
# Differenced Cereals Price Index to Diffe -0.0329    0.053      -0.6206  0.5348   (-0.1368 | 0.071)
# Differenced Oils Price Index to Differen -0.1529    0.064      -2.3899  0.0169   (-0.2782 | -0.0275)
# Differenced Temperature to Differenced S 3.417      0.1247     27.3941  0.0      (3.1725 | 3.6615)
# Differenced Temperature Constant         0.0005     0.0017     0.2831   0.7771   (-0.0029 | 0.0039)
# Differenced Temperature AR(1)            -0.0012    0.0138     -0.0882  0.9297   (-0.0282 | 0.0257)
# Differenced Meat Price Index to Differen 0.0007     0.0244     0.0291   0.9768   (-0.047 | 0.0485)
# Differenced Dairy Price Index to Differe -0.0008    0.0236     -0.0349  0.9721   (-0.0472 | 0.0455)
# Differenced Cereals Price Index to Diffe 0.0052     0.0285     0.1819   0.8557   (-0.0507 | 0.0611)
# Differenced Oils Price Index to Differen -0.0016    0.0556     -0.0281  0.9776   (-0.1106 | 0.1075)
# Differenced Sugar Price Index to Differe -0.3362    0.0008     -434.755 0.0      (-0.3377 | -0.3347)
# Differenced Temperature AR(2)            0.0042     0.9579     0.0043   0.9965   (-1.8732 | 1.8816)
# Differenced Meat Price Index to Differen -0.0004    1.6971     -0.0003  0.9998   (-3.3267 | 3.3258)
# Differenced Dairy Price Index to Differe -0.0026    1.6472     -0.0016  0.9988   (-3.2311 | 3.2259)
# Differenced Cereals Price Index to Diffe -0.0007    1.9872     -0.0003  0.9997   (-3.8955 | 3.8942)
# Differenced Oils Price Index to Differen 0.0014     3.875      0.0004   0.9997   (-7.5937 | 7.5965)
# Differenced Sugar Price Index to Differe -0.12      0.0539     -2.2278  0.0259   (-0.2256 | -0.0144)
# ==========================================================================================================

# %%
VAR_model.plot_z(list(range(0,6)),figsize=(15,5))

# %%
VAR_model.plot_fit(figsize=(15,5))

# %%
VAR_model.plot_predict(past_values=19, h=5, figsize=(15,5))

# %%
VAR_model.plot_predict_is(h=30, figsize=((15,5)))

# %%
pfarima_model = pf.ARIMA(data=indexed_df, ar=4, ma=4, target='Sugar Price Index', family=pf.Normal())

# %%
arima_x = pfarima_model.fit("MLE")
arima_x.summary()
# Out:
# Normal ARIMA(4,0,4)
# ======================================================= ==================================================
# Dependent Variable: Sugar Price Index                   Method: MLE
# Start Date: 1990-05-01 00:00:00                         Log Likelihood: -1426.5311
# End Date: 2017-12-01 00:00:00                           AIC: 2873.0623
# Number of observations: 332                             BIC: 2911.1136
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# Constant                                 181.9718   24.3129    7.4846   0.0      (134.3185 | 229.6252)
# AR(1)                                    -0.4424    0.0473     -9.3538  0.0      (-0.5351 | -0.3497)
# AR(2)                                    -0.1447    0.0551     -2.6259  0.0086   (-0.2527 | -0.0367)
# AR(3)                                    -0.0771    0.0519     -1.4877  0.1368   (-0.1788 | 0.0245)
# AR(4)                                    0.6313     0.045      14.0449  0.0      (0.5432 | 0.7194)
# MA(1)                                    1.7941     0.0016     1157.449 0.0      (1.791 | 1.7971)
# MA(2)                                    1.8042     0.0046     394.9082 0.0      (1.7953 | 1.8132)
# MA(3)                                    1.5083     0.0042     359.1482 0.0      (1.5001 | 1.5165)
# MA(4)                                    0.4955     0.0008     656.9081 0.0      (0.494 | 0.4969)
# Normal Scale                             17.3824
# ==========================================================================================================

# %%
arima_x_mh = pfarima_model.fit("M-H")
arima_x_mh.summary()
# Out:
# Acceptance rate of Metropolis-Hastings is 0.06045
# Acceptance rate of Metropolis-Hastings is 0.1232
# Acceptance rate of Metropolis-Hastings is 0.2254
# Acceptance rate of Metropolis-Hastings is 0.43625
# Acceptance rate of Metropolis-Hastings is 0.16365
# Acceptance rate of Metropolis-Hastings is 0.1925
# Acceptance rate of Metropolis-Hastings is 0.1002
# Acceptance rate of Metropolis-Hastings is 0.3222
#
# Tuning complete! Now sampling.
# Acceptance rate of Metropolis-Hastings is 0.498675
# Acceptance rate of Metropolis-Hastings is 0.3574
# Normal ARIMA(4,0,4)
# ======================================================= ==================================================
# Dependent Variable: Sugar Price Index                   Method: Metropolis Hastings
# Start Date: 1990-05-01 00:00:00                         Unnormalized Log Posterior: -1390.1358
# End Date: 2017-12-01 00:00:00                           AIC: 2800.2716097934135
# Number of observations: 332                             BIC: 2838.3229594825784
# ==========================================================================================================
# Latent Variable                          Median             Mean               95% Credibility Interval
# ======================================== ================== ================== =========================
# Constant                                 1.139              1.2794             (-3.0922 | 6.1242)
# AR(1)                                    -0.2454            -0.2434            (-0.3036 | -0.175)
# AR(2)                                    0.1667             0.1679             (0.1088 | 0.2305)
# AR(3)                                    0.2392             0.2357             (0.1667 | 0.2917)
# AR(4)                                    0.667              0.6702             (0.609 | 0.7372)
# MA(1)                                    1.8033             1.8033             (1.7994 | 1.8075)
# MA(2)                                    1.8177             1.8158             (1.8064 | 1.8232)
# MA(3)                                    1.4777             1.4785             (1.4714 | 1.4892)
# MA(4)                                    0.5102             0.5109             (0.508 | 0.5137)
# Normal Scale                             15.4053            15.4197            (14.47 | 16.4916)
# ==========================================================================================================

# %%
pfarima_model.plot_z(figsize=(15,5))

# %%
pfarima_model.plot_fit(figsize=(15,10))

# %%
pfarima_model.plot_predict_is(h=50, figsize=(15,5))

# %% [markdown]
# # Forecasting

# %% [markdown]
# # dashboard code?
